# %%
import requests

# your list, e.g.
packages = [
    "basis-set-exchange", "biopython", "dgl", "dgllife", "dm-haiku", "flake8", "flaky", "gensim", "h5py", "jax", "jaxlib", "lightgbm", "lightning", "matminer", "mordred", "mypy", "networkx", "numpy", "optax", "pillow", "pre-commit", "pubchempy", "pyGPGO", "pydantic", "pymatgen", "pymc", "pysam", "pyscf", "pytest", "pytest-cov", "python-Levenshtein", "rdkit", "scipy", "simdna", "tensorboard", "tensorflow", "tensorflow_addons", "tensorflow_probability", "tokenizers", "torch-cluster", "torch-geometric", "torch", "torchdata", "transformers", "types-setuptools", "xgboost", "yapf"
]

git_repos = [
    "git+https://github.com/diffqc/dqclibs.git", "git+https://gitlab.com/libxc/libxc.git@6.0.0",
]

def parse_name_ver(spec):
    if "==" in spec:
        return tuple(spec.split("=="))
    else:
        return spec, None

for spec in packages:
    name, ver = parse_name_ver(spec)
    url = f"https://pypi.org/pypi/{name}/json"
    r = requests.get(url)
    if not r.ok:
        print(f"{name:20s}  ERROR fetching metadata")
        continue

    data = r.json()
    releases = data["releases"]
    # pick either specified version or latest
    files = releases[ver] if ver else data["urls"]
    if not files:
        print(f"{name:20s}  no files found for {ver or 'latest'}")
        continue

    # choose the first wheel (or sdist) in the list
    chosen = None
    for filemeta in (files if ver else files):
        # prefer a wheel over sdist
        if filemeta["packagetype"] == "bdist_wheel":
            chosen = filemeta
            break
    if not chosen:
        chosen = files[0]

    size_mb = chosen["size"] / 1024**2
    fn = chosen["filename"]
    print(f"{name:25s} {size_mb:6.2f} MB  ({fn})")
# Out:
# basis-set-exchange         36.84 MB  (basis_set_exchange-0.11-py3-none-any.whl)
# biopython                   2.66 MB  (biopython-1.85-cp310-cp310-macosx_10_9_x86_64.whl)
# dgl                         5.09 MB  (dgl-2.2.1-cp310-cp310-win_amd64.whl)
# dgllife                     0.22 MB  (dgllife-0.3.2-py3-none-any.whl)
# dm-haiku                    0.36 MB  (dm_haiku-0.0.14-py3-none-any.whl)
# flake8                      0.06 MB  (flake8-7.3.0-py2.py3-none-any.whl)
# flaky                       0.02 MB  (flaky-3.8.1-py2.py3-none-any.whl)
# gensim                     22.97 MB  (gensim-4.3.3-cp310-cp310-macosx_10_9_x86_64.whl)
# h5py                        3.18 MB  (h5py-3.14.0-cp310-cp310-macosx_10_9_x86_64.whl)
# jax                         2.60 MB  (jax-0.6.2-py3-none-any.whl)
# jaxlib                     51.78 MB  (jaxlib-0.6.2-cp310-cp310-macosx_11_0_arm64.whl)
# lightgbm                    1.92 MB  (lightgbm-4.6.0-py3-none-macosx_10_15_x86_64.whl)
# lightning                   0.78 MB  (lightning-2.5.2-py3-none-any.whl)
# matminer                    5.25 MB  (matminer-0.9.3-py3-none-any.whl)
# mordred                     0.12 MB  (mordred-1.2.0.tar.gz)
# mypy                       10.45 MB  (mypy-1.16.1-cp310-cp310-macosx_10_9_x86_64.whl)
# networkx                    1.94 MB  (networkx-3.5-py3-none-any.whl)
# numpy                      20.22 MB  (numpy-2.3.1-cp311-cp311-macosx_10_9_x86_64.whl)
# optax                       0.34 MB  (optax-0.2.5-py3-none-any.whl)
# pillow                      5.07 MB  (pillow-11.3.0-cp310-cp310-macosx_10_10_x86_64.whl)
# pre-commit                  0.21 MB  (pre_commit-4.2.0-py2.py3-none-any.whl)
# pubchempy                   0.03 MB  (PubChemPy-1.0.4.tar.gz)
# pyGPGO                      0.01 MB  (pyGPGO-0.5.1.tar.gz)
# pydantic                    0.42 MB  (pydantic-2.11.7-py3-none-any.whl)
# pymatgen                    3.52 MB  (pymatgen-2025.6.14-cp310-cp310-macosx_10_9_x86_64.whl)
# pymc                        0.50 MB  (pymc-5.23.0-py3-none-any.whl)
# pysam                       5.89 MB  (pysam-0.23.3-cp310-cp310-macosx_10_9_x86_64.whl)
# pyscf                      33.94 MB  (pyscf-2.9.0-py3-none-macosx_10_9_x86_64.whl)
# pytest                      0.35 MB  (pytest-8.4.1-py3-none-any.whl)
# pytest-cov                  0.02 MB  (pytest_cov-6.2.1-py3-none-any.whl)
# python-Levenshtein          0.01 MB  (python_levenshtein-0.27.1-py3-none-any.whl)
# rdkit                      28.69 MB  (rdkit-2025.3.3-cp310-cp310-macosx_10_15_x86_64.whl)
# scipy                      34.76 MB  (scipy-1.16.0-cp311-cp311-macosx_10_14_x86_64.whl)
# simdna                      0.61 MB  (simdna-0.4.3.2.tar.gz)
# tensorboard                 5.25 MB  (tensorboard-2.19.0-py3-none-any.whl)
# tensorflow                240.77 MB  (tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl)
# tensorflow_addons          13.48 MB  (tensorflow_addons-0.23.0-cp310-cp310-macosx_10_14_x86_64.whl)
# tensorflow_probability      6.66 MB  (tensorflow_probability-0.25.0-py2.py3-none-any.whl)
# tokenizers                  2.74 MB  (tokenizers-0.21.2-cp39-abi3-macosx_10_12_x86_64.whl)
# torch-cluster               0.05 MB  (torch_cluster-1.6.3.tar.gz)
# torch-geometric             1.08 MB  (torch_geometric-2.6.1-py3-none-any.whl)
# torch                      94.50 MB  (torch-2.7.1-cp310-cp310-manylinux_2_28_aarch64.whl)
# torchdata                   0.06 MB  (torchdata-0.11.0-py3-none-any.whl)
# transformers               10.32 MB  (transformers-4.53.1-py3-none-any.whl)
# types-setuptools            0.06 MB  (types_setuptools-80.9.0.20250529-py3-none-any.whl)
# xgboost                     2.14 MB  (xgboost-3.0.2-py3-none-macosx_10_15_x86_64.whl)
# yapf                        0.24 MB  (yapf-0.43.0-py3-none-any.whl)
